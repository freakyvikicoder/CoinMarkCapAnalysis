# %%
from datetime import date,timedelta
import pandas as pd
import re
import numpy as np

# %%
def allSundays(year):
   d = date(year, 1, 1)
   d += timedelta(days = 6 - d.weekday())
   while d.year == year:
      yield d
      d += timedelta(days = 7)

# %%
allSundaysList = []
for d in allSundays(2017):
    allSundaysList.append(str(d).replace('-',''))

# %%
#constants or configuration settings
pd.set_option('display.float_format', lambda x: '%.8f' % x)
reCleanSplChars = re.compile(r'[a-zA-Z \t$%,?<>]*')

# %%
def GetDataAndProcess(weekendDate):
    #import pdb;pdb.set_trace()
    snapshotUrl = 'https://coinmarketcap.com/historical/{0}/'.format(weekendDate)
    snapshotCoinDf = pd.read_html(snapshotUrl)[0]
    snapshotCoinDf.rename(columns={'#':'RankNum'},inplace=True)
    
    snapshotCoinDf['PriceClean'] = snapshotCoinDf['Price'].str.replace(reCleanSplChars,'').str.replace(r'[0-9]*(-)[0-9]*','')
    snapshotCoinDf['Volume24hClean'] = snapshotCoinDf['Volume (24h)'].str.replace(reCleanSplChars,'')
    snapshotCoinDf['P7dClean'] = snapshotCoinDf['% 7d'].str.replace(reCleanSplChars,'')
    snapshotCoinDf['PriceClean'] = pd.to_numeric(snapshotCoinDf['PriceClean'])
    snapshotCoinDf['Volume24hClean'] = pd.to_numeric(snapshotCoinDf['Volume24hClean'])
    snapshotCoinDf['P7dClean'] = pd.to_numeric(snapshotCoinDf['P7dClean'])
    return(snapshotCoinDf)

# %%
def filterGroupNCalcData(cleanedDataFrame):
    tempDf = cleanedDataFrame[(cleanedDataFrame['PriceClean']>0.0001) & (cleanedDataFrame['PriceClean']<0.01)].copy()
    return(tempDf['P7dClean'].groupby(pd.cut(tempDf['Volume24hClean'],[100,1000,10000,tempDf.Volume24hClean.max()]
                                             ,labels=['100-1000','1000-10000','10000-MaxVol'])).mean())

# %%
masterListVar = []
#for iDay in allSundaysList:
for iDay in ['20170326']:
    t = 'tsDataFrame_'+iDay
    s = 'summaryDf_'+iDay
    dictDf = {}
    dictDf[t] = GetDataAndProcess(iDay).copy()
    dictDf[s] = filterGroupNCalcData(dictDf[t]).copy()
    ##tsDataFrame_+iDay = GetDataAndProcess(iDay).copy()
    ##summaryDf_+iDay = filterGroupNCalcData(tsDataFrame_+iDay).copy()
    masterListVar.append({'forDate':iDay,'dataSet':dictDf[t],'summaryDataSet':dictDf[s]})

# %%
excelWriterStream = pd.ExcelWriter('CoinsSummaryAnalysis.xlsx',engine='xlsxwriter')
finalSummaryDf = pd.DataFrame()
for mlv in masterListVar:
    #print(mlv['forDate']);
    #print(mlv['summaryDataSet'])
    mlv['dataSet'].to_excel(excelWriterStream,sheet_name=mlv['forDate'])
    mlv['summaryDataSet'].rename(mlv['forDate'],inplace=True)
    finalSummaryDf[mlv['forDate']] = mlv['summaryDataSet']

finalSummaryDf.to_excel(excelWriterStream,sheet_name='Summary')
excelWriterStream.save()

# %%
testMarchDf = pd.DataFrame(masterListVar[0]['dataSet']).copy()

# %%
masterListVar[0]['summaryDataSet']
# Out:
# Volume24hClean
# 100-1000        8.72200000
# 1000-10000     42.53666667
# 10000-MaxVol   42.06088235
# Name: P7dClean, dtype: float64

# %%
testMarchDf[(testMarchDf['PriceClean']>0.0001) & (testMarchDf['PriceClean']<0.01)]
# Out:
#      RankNum                     Name    Symbol    Market Cap      Price  \
# 3          4              XRP  Ripple       XRP  $353,371,097  $0.009451
# 17        18           DOGE  Dogecoin      DOGE   $32,195,923  $0.000296
# 28        29             XLM  Stellar       XLM   $14,721,350  $0.002072
# 31        32           BTS  BitShares       BTS   $13,576,190  $0.005239
# 35        36              SC  Siacoin        SC   $12,500,391  $0.000511
# 54        55             ROUND  Round     ROUND    $5,648,484  $0.006645
# 65        66              BAY  BitBay       BAY    $3,486,959  $0.003461
# 72        73            DGB  DigiByte       DGB    $2,486,168  $0.000307
# 75        76             BURST  Burst     BURST    $2,372,813  $0.001368
# 77        78            VASH  VPNCoin      VASH    $2,260,103  $0.005645
# 79        80            GRC  GridCoin       GRC    $2,195,271  $0.005653
# 82        83      PEPECASH  Pepe Cash  PEPECASH    $1,979,763  $0.002821
# 104      105         FTC  Feathercoin       FTC    $1,560,997  $0.009987
# 114      115         ENRG  Energycoin      ENRG    $1,127,686  $0.009338
# 115      116           EAC  EarthCoin       EAC    $1,101,052  $0.000118
# 127      128          FLO  FlorinCoin       FLO      $945,597  $0.007614
# 134      135  SAFEX  Safe Exchange...     SAFEX      $813,743  $0.000379
# 142      143         XDN  DigitalNote       XDN      $738,354  $0.000107
# 144      145        BPC  Bitpark Coin       BPC      $717,068  $0.009561
# 145      146             NOTE  DNotes      NOTE      $697,567  $0.006290
# 152      153              XHI  HiCoin       XHI      $614,423  $0.003238
# 153      154           SCOT  Scotcoin      SCOT      $598,763  $0.000599
# 155      156        FLDC  FoldingCoin      FLDC      $593,248  $0.001274
# 156      157           WDC  WorldCoin       WDC      $559,754  $0.004926
# 159      160         GRS  Groestlcoin       GRS      $537,311  $0.008014
# 163      164               RISE  Rise      RISE      $493,869  $0.004599
# 166      167             VISIO  Visio     VISIO      $444,463  $0.008858
# 167      168            NSR  NuShares       NSR      $437,664  $0.000162
# 168      169        EMC2  Einsteinium      EMC2      $428,073  $0.002048
# 172      173               QRK  Quark       QRK      $410,045  $0.001640
# ..       ...                      ...       ...           ...        ...
# 658      659          RICHX  RichCoin     RICHX             ?  $0.000628
# 659      660          RUBIT  RubleBit     RUBIT             ?  $0.000521
# 660      661             CNC  CHNCoin       CNC             ?  $0.000515
# 661      662             BXC  Bitcedi       BXC             ?  $0.000445
# 662      663        SPORT  SportsCoin     SPORT             ?  $0.000425
# 663      664     FRWC  FrankyWillCoin      FRWC             ?  $0.000415
# 664      665           MOTO  Motocoin      MOTO             ?  $0.000404
# 665      666    DBG  Digital Bulli...       DBG             ?  $0.000338
# 666      667             MMXVI  MMXVI     MMXVI             ?  $0.000336
# 667      668             DUB  Dubstep       DUB             ?  $0.000290
# 668      669             GMB  Gambleo       GMB             ?  $0.000290
# 669      670         TODAY  TodayCoin     TODAY             ?  $0.000276
# 670      671           SOON  SoonCoin      SOON             ?  $0.000271
# 671      672           OPES  Opescoin      OPES             ?  $0.000242
# 672      673         BRAIN  Braincoin     BRAIN             ?  $0.000242
# 673      674        WSX  WeAreSatoshi       WSX             ?  $0.000213
# 674      675           QBC  Quebecoin       QBC             ?  $0.000210
# 675      676         LAZ  Lazaruscoin       LAZ             ?  $0.000200
# 676      677           MONETA  Moneta    MONETA             ?  $0.000182
# 677      678        BCF  Bitcoin Fast       BCF             ?  $0.000141
# 678      679           MARX  MarxCoin      MARX             ?  $0.000138
# 679      680              GAIN  UGAIN      GAIN             ?  $0.000126
# 680      681           DISK  DarkLisk      DISK             ?  $0.000120
# 681      682        CBD  CBD Crystals       CBD             ?  $0.000115
# 682      683   GBRC  Global Busine...      GBRC             ?  $0.000110
# 683      684         NNC  NicNac Coin       NNC             ?  $0.000107
# 684      685        EB3C  EuroBitCoin      EB3C             ?  $0.000107
# 685      686          PRM  PrismChain       PRM             ?  $0.000106
# 686      687        BAC  BitAlphaCoin       BAC             ?  $0.000104
# 687      688              OP  Operand        OP             ?  $0.000101
#
#     Circulating Supply Volume (24h)    % 1h    % 24h     % 7d  PriceClean  \
# 3    37,388,960,792  *   $9,880,955   0.39%   -7.69%   41.14%  0.00945100
# 17        108686658467   $1,645,108   0.06%   14.05%   33.75%  0.00029600
# 28    7,104,805,570  *     $641,797   0.25%   -1.20%    6.29%  0.00207200
# 31    2,591,243,958  *     $382,187   0.14%   -1.66%   15.61%  0.00523900
# 35         24448089084     $246,787   0.85%    4.51%   36.98%  0.00051100
# 54      850,000,000  *      $54,621   0.19%   13.84%   11.48%  0.00664500
# 65    1,007,391,220  *      $49,595  -0.09%   22.15%   80.38%  0.00346100
# 72          8107031908      $39,256   0.10%   -2.85%   23.51%  0.00030700
# 75          1734465449      $50,046   0.27%   11.09%   34.30%  0.00136800
# 77      400,339,746  *     $136,906   1.24%    9.31%   12.74%  0.00564500
# 79           388339577       $7,727  -0.01%    8.89%    1.65%  0.00565300
# 82      701,884,009  *      $12,754   0.23%   20.82%   80.43%  0.00282100
# 104          156302593       $9,436   0.14%   -3.28%   32.11%  0.00998700
# 114          120757998      $22,160   0.01%   49.34%   96.87%  0.00933800
# 115         9346468332      $36,165   0.12%    9.17%   19.39%  0.00011800
# 127          124197561       $5,140  -0.01%    1.28%   58.70%  0.00761400
# 134   2,147,483,647  *       $2,428  -0.05%   -3.63%   26.47%  0.00037900
# 142         6877598446      $40,308   0.11%    5.95%    6.47%  0.00010700
# 144      75,000,000  *      Low Vol   1.61%   -0.42%  -23.19%  0.00956100
# 145          110895736      $34,508  -0.31%   -3.09%   21.94%  0.00629000
# 152          189729990      $79,167  -1.52%  -19.71%   18.42%  0.00323800
# 153   1,000,000,000  *      Low Vol   0.26%  -36.07%  151.59%  0.00059900
# 155     465,833,654  *      $12,885   0.22%    7.03%   12.58%  0.00127400
# 156          113639798       $2,100   0.41%   -3.90%   -1.21%  0.00492600
# 159           67050555      $17,096   0.06%    6.09%   72.59%  0.00801400
# 163     107,387,215  *       $5,152  -0.44%   13.01%   83.25%  0.00459900
# 166      50,179,227  *       $1,968  -0.09%   -5.36%  -36.25%  0.00885800
# 167   2,702,268,334  *       $2,776  -0.28%    7.62%   15.86%  0.00016200
# 168          209009478      $15,971  -0.33%   -3.76%   32.39%  0.00204800
# 172          250101047       $2,360   0.04%   23.13%   52.75%  0.00164000
# ..                 ...          ...     ...      ...      ...         ...
# 658                  ?      Low Vol   0.00%    5.42%    3.90%  0.00062800
# 659                  ?      Low Vol  -1.48%    4.23%   12.93%  0.00052100
# 660                  ?         $553  -0.34%    6.41%    7.05%  0.00051500
# 661                  ?         $754   4.62%  154.65%  240.08%  0.00044500
# 662               ?  *      Low Vol   0.06%    7.06%  -15.02%  0.00042500
# 663                  ?      Low Vol   0.24%        ?   14.46%  0.00041500
# 664                  ?      Low Vol   2.15%   29.59%   41.13%  0.00040400
# 665               ?  *      Low Vol   0.26%    4.38%        ?  0.00033800
# 666                  ?      Low Vol  -2.53%   -4.40%   19.17%  0.00033600
# 667               ?  *      Low Vol   0.06%   -0.95%   15.22%  0.00029000
# 668               ?  *      Low Vol   0.06%   22.91%        ?  0.00029000
# 669                  ?      Low Vol   1.24%   18.07%    1.87%  0.00027600
# 670               ?  *      Low Vol   0.00%    5.25%   58.26%  0.00027100
# 671                  ?      Low Vol   0.06%    4.54%   -6.12%  0.00024200
# 672               ?  *      Low Vol   0.06%   -6.66%    0.02%  0.00024200
# 673                  ?       $1,107  -0.42%    4.99%   32.23%  0.00021300
# 674                  ?      Low Vol  -0.80%   13.74%    2.64%  0.00021000
# 675               ?  *      Low Vol  -0.67%        ?   -8.31%  0.00020000
# 676                  ?      $25,821   5.36%  150.73%  281.81%  0.00018200
# 677                  ?      Low Vol   0.06%    1.63%   -6.65%  0.00014100
# 678                  ?      Low Vol   0.10%   -7.23%   -5.73%  0.00013800
# 679                  ?      Low Vol   0.26%   11.28%    5.22%  0.00012600
# 680                  ?      Low Vol   2.13%   41.96%   18.95%  0.00012000
# 681               ?  *      Low Vol  -0.34%   21.60%  -48.09%  0.00011500
# 682                  ?      Low Vol  -0.68%  -12.50%  -80.53%  0.00011000
# 683                  ?      Low Vol   0.36%    5.18%        ?  0.00010700
# 684                  ?      Low Vol  -1.32%   -5.30%  -94.65%  0.00010700
# 685               ?  *      Low Vol   0.26%   27.57%   50.64%  0.00010600
# 686                  ?      Low Vol   0.07%  -11.14%  -49.33%  0.00010400
# 687               ?  *      Low Vol   2.52%   11.24%    0.20%  0.00010100
#
#       Volume24hClean     P7dClean
# 3   9880955.00000000  41.14000000
# 17  1645108.00000000  33.75000000
# 28   641797.00000000   6.29000000
# 31   382187.00000000  15.61000000
# 35   246787.00000000  36.98000000
# 54    54621.00000000  11.48000000
# 65    49595.00000000  80.38000000
# 72    39256.00000000  23.51000000
# 75    50046.00000000  34.30000000
# 77   136906.00000000  12.74000000
# 79     7727.00000000   1.65000000
# 82    12754.00000000  80.43000000
# 104    9436.00000000  32.11000000
# 114   22160.00000000  96.87000000
# 115   36165.00000000  19.39000000
# 127    5140.00000000  58.70000000
# 134    2428.00000000  26.47000000
# 142   40308.00000000   6.47000000
# 144              nan -23.19000000
# 145   34508.00000000  21.94000000
# 152   79167.00000000  18.42000000
# 153              nan 151.59000000
# 155   12885.00000000  12.58000000
# 156    2100.00000000  -1.21000000
# 159   17096.00000000  72.59000000
# 163    5152.00000000  83.25000000
# 166    1968.00000000 -36.25000000
# 167    2776.00000000  15.86000000
# 168   15971.00000000  32.39000000
# 172    2360.00000000  52.75000000
# ..               ...          ...
# 658              nan   3.90000000
# 659              nan  12.93000000
# 660     553.00000000   7.05000000
# 661     754.00000000 240.08000000
# 662              nan -15.02000000
# 663              nan  14.46000000
# 664              nan  41.13000000
# 665              nan          nan
# 666              nan  19.17000000
# 667              nan  15.22000000
# 668              nan          nan
# 669              nan   1.87000000
# 670              nan  58.26000000
# 671              nan  -6.12000000
# 672              nan   0.02000000
# 673    1107.00000000  32.23000000
# 674              nan   2.64000000
# 675              nan  -8.31000000
# 676   25821.00000000 281.81000000
# 677              nan  -6.65000000
# 678              nan  -5.73000000
# 679              nan   5.22000000
# 680              nan  18.95000000
# 681              nan -48.09000000
# 682              nan -80.53000000
# 683              nan          nan
# 684              nan -94.65000000
# 685              nan  50.64000000
# 686              nan -49.33000000
# 687              nan   0.20000000
#
# [318 rows x 13 columns]
